# %%
import pandas as pd
import numpy as np
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import seaborn as sns
import matplotlib.pyplot as plt
import geopandas as gpd
import descartes
from shapely.geometry import Point, Polygon

# %%
df = pd.read_csv('data/train.csv')
plt.style.use('default')
plt.rcParams['figure.figsize'] = [12.0,8.0]

# %% [markdown]
# ## WordCloud de palabras en descripcion de los anuncios totales.

# %% [markdown]
# No puedo hacer esta, tarda demasiado o el kernel muere

# %%
text = "".join(str(descripcion) for descripcion in ciudad.descripcion)

# %%
wordcloud = WordCloud().generate(text)

# %%
plt.figure(figsize = (8,8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad=0)

plt.show()

# %% [markdown]
# ## WordCloud de palabras en titulos de anuncios totales

# %%
titulos_tot = "".join(str(title) for title in df.titulo)

# %%
wordcloud = WordCloud().generate(titulos_tot)

# %%
plt.figure(figsize = (8,8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad=0)

plt.show()

# %% [markdown]
# ## WordCloud de palabras en descripcion de los anuncios de Distrito Federal.

# %%
ciudad = df[df["provincia"] == "Distrito Federal"]

# %%
text = "".join(str(descripcion) for descripcion in ciudad.descripcion)

# %%
wordcloud = WordCloud().generate(text)

# %%
plt.figure(figsize = (8,8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad=0)

plt.show()

# %% [markdown]
# ## WordCloud de palabras en titulos de anuncios de Distrito Federal

# %%
titulos = "".join(str(title) for title in ciudad.titulo)

# %%
wordcloud = WordCloud().generate(titulos)

# %%
plt.figure(figsize = (8,8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad=0)

plt.show()
