# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import geopandas as gpd
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import descartes
from shapely.geometry import Point, Polygon

# %%
df = pd.read_csv('data/train.csv')
plt.style.use('default')
plt.rcParams['figure.figsize'] = [12.0,8.0]

# %%
df["descripcion"] = df["descripcion"].map(lambda x : str(x).lower().split())

# %%
df["titulo"] = df["titulo"].map(lambda x : str(x).lower().split())

# %%
def wordcount(dic,serie):
    for lista in serie:
        for x in lista:
            if x in dic:
                dic[x]+=1
            else:
                dic[x]=1

# %%
dic = {}
wordcount(dic,df["descripcion"])

# %%
dic
# Out:
# {'depto.': 1610,
#  'interior': 4774,
#  'de': 1043866,
#  '80.15m2,': 1,
#  'consta': 16491,
#  'sala': 78191,
#  'comedor': 35849,
#  'cocina': 116751,
#  'equipada,': 13323,
#  'área': 49518,
#  'lavado,': 24364,
#  'baño': 131503,
#  'completo,': 23152,
#  'recamara': 29274,
#  'principal': 55544,
#  'con': 586130,
#  'closet': 27580,
#  'y': 511191,
#  'completo.': 9206,
#  '2da.': 310,
#  'closet.': 2181,
#  '<p>entre': 30,
#  'sonora': 36,
#  'guerrero,': 174,
#  'atr&aacute;s': 214,
#  'del': 75528,
#  'hospital': 1804,
#  '&aacute;ngeles': 52,
#  'pedregal,': 570,
#  'en': 392227,
#  'excelente': 57262,
#  'estado': 8486,
#  'conservaci&oacute;n,': 208,
#  'construida': 4601,
#  '3': 110568,
#  'niveles,': 12779,
#  'estacionamiento': 42087,
#  'para': 197501,
#  '2': 163353,
#  'autos,': 20632,
#  'rec&aacute;maras': 3214,
#  'pisos': 20195,
#  'madera': 12055,
#  'natural': 2975,
#  'la': 239155,
#  'vestidor': 28571,
#  'ba&ntilde;o,': 6426,
#  'ba&ntilde;os': 5191,
#  'completos': 6872,
#  'muros': 3871,
#  'loseta': 6227,
#  'espa&ntilde;ola,': 17,
#  'canceler&iacute;a': 113,
#  'aluminio,': 1662,
#  'medios': 2098,
#  'ba&ntilde;os,': 4496,
#  'integral': 31674,
#  'piso': 29284,
#  't.v.,': 2988,
#  'vest&iacute;bulo,': 200,
#  'madera,': 4800,
#  'l&iacute;nea': 225,
#  'telef&oacute;nica,': 108,
#  'terraza': 26529,
#  'techada': 13020,
#  'policarbonato': 133,
#  'puede': 12155,
#  'ser': 6081,
#  'antecomedor,': 3185,
#  'cuarto': 71321,
#  'servicio': 46708,
#  'loseta,': 1157,
#  'fachada': 2304,
#  'policarbonato..&nbsp;': 1,
#  '4': 30123,
#  'casas</p>': 28,
#  'descripcion': 446,
#  'mejor': 9393,
#  'ubicacion': 4822,
#  'residencial': 11082,
#  'el': 103045,
#  'oriente': 1032,
#  'ciudad': 7921,
#  'urbi': 399,
#  'versalles,': 57,
#  'te': 12651,
#  'invito': 437,
#  'a': 163824,
#  'compartir': 357,
#  'una': 90880,
#  'nueva': 9495,
#  'forma': 1902,
#  'vida': 1927,
#  'zona': 29296,
#  'urbana': 158,
#  'guadalajara': 385,
#  'desarrollo': 7203,
#  'su': 31717,
#  'tipo,': 216,
#  'ven': 1583,
#  'descubre': 122,
#  'un': 105311,
#  'concepto': 1141,
#  'unico:': 16,
#  '\x95': 23311,
#  'por': 40505,
#  'amplitud': 611,
#  'tranquilidad.': 276,
#  'seguridad': 12890,
#  'confort.': 192,
#  'diseños.': 33,
#  'sus': 7972,
#  'bellos': 301,
#  'terminados.': 208,
#  'precio': 19636,
#  'mercado.': 295,
#  'exelente': 720,
#  'ubicación,': 6235,
#  'estamos': 1167,
#  'cerca': 34323,
#  'todo': 12512,
#  'todos!': 15,
#  'vias': 1923,
#  'comunicacions': 18,
#  'rapidas': 309,
#  'modernas.': 35,
#  'centros': 12987,
#  'comerciales': 7852,
#  'dentro': 10661,
#  'fraccionamiento': 21960,
#  '.': 24344,
#  'bello': 549,
#  'ingreso': 1047,
#  'privado': 7979,
#  'vigilado.': 17,
#  'acceso': 22917,
#  'controlado': 2391,
#  'cada': 21204,
#  'coto,': 587,
#  'guardias': 112,
#  'vigilancia': 25490,
#  'video.': 41,
#  'perimetro': 55,
#  'totalmente': 9892,
#  'cerrado.': 580,
#  'cableado': 565,
#  'oculto.': 33,
#  'amplios': 11675,
#  'jardines': 4566,
#  'areas': 7716,
#  'verdes.': 1974,
#  'infantiles': 2186,
#  'deportivos.': 61,
#  'escuelas,': 7725,
#  'comerciales,': 7965,
#  'hospitales,': 1825,
#  'farmacias': 274,
#  'lo': 14100,
#  'que': 64409,
#  'necesitas': 247,
#  'mano.': 319,
#  'tranquilidad': 2292,
#  'garantizada.': 217,
#  'recamaras,': 43754,
#  'amplia': 26466,
#  'sala,': 46650,
#  ',': 47410,
#  '1/2': 14469,
#  'baños,': 27853,
#  'independiente': 5279,
#  'amplio': 19872,
#  'patio': 46283,
#  'trasero,': 3266,
#  'es': 34663,
#  'master': 494,
#  'room': 1819,
#  'autos.': 11134,
#  'independiente,': 2769,
#  'pasillo': 5149,
#  'servicio,': 25776,
#  'propios.': 742,
#  'bonito': 5138,
#  'proyecto': 4853,
#  'ampliacion.': 72,
#  'mayores': 4059,
#  'informes': 10243,
#  'comunicarse': 3155,
#  'alos': 46,
#  'siguientes': 1781,
#  'numeros': 108,
#  'concretar': 479,
#  'cita': 7329,
#  'conoscas': 35,
#  'casa': 135621,
#  'srta.': 422,
#  'lissette': 201,
#  'cel./': 366,
#  'privada': 12006,
#  'caseta': 5532,
#  'casas': 11750,
#  'dos': 75187,
#  'tres': 25291,
#  'dies': 1,
#  'minutos': 19449,
#  'centro': 13916,
#  'toluca': 758,
#  'costado': 1996,
#  'valle': 3989,
#  'zamarrero': 16,
#  'escuelas': 6468,
#  'aceptamos': 5751,
#  'todos': 18597,
#  'los': 55036,
#  'tipos': 557,
#  'credito': 5426,
#  'infonavit,cofinavit,fovissste,aliados,shf.asesor': 1,
#  'certificado': 280,
#  'contactame': 164,
#  'si': 7330,
#  'deseas': 238,
#  'fotos': 545,
#  'presentacion': 19,
#  'o': 40613,
#  'concertar': 637,
#  'cel.': 4744,
#  'email:': 280,
#  'departamento': 40432,
#  'excelentes': 12758,
#  'condiciones': 4119,
#  'muy': 71212,
#  'buena': 11151,
#  'listo': 2531,
#  'habitar': 701,
#  'llamenos': 597,
#  '!!!!!': 148,
#  'departamento,': 3494,
#  'estancia': 13160,
#  'pared': 3522,
#  'granito': 7142,
#  'mármol,': 1745,
#  'recamaras': 65797,
#  'closet,': 13143,
#  'integral,': 24614,
#  'baño,': 40988,
#  'laminado,': 1525,
#  'recién': 2819,
#  'remodelado,': 1060,
#  'ubicación': 12679,
#  'excelente.': 157,
#  'ubicada': 18243,
#  'esquina,': 2527,
#  'pertenece': 101,
#  'san': 13326,
#  'lorenzo': 180,
#  'agencia': 81,
#  'santiago': 479,
#  'etla.': 10,
#  'cuenta': 87955,
#  'con:': 7790,
#  'baños': 36938,
#  'comedor-': 71,
#  'cisterna': 10052,
#  'fosa': 310,
#  'séptica': 101,
#  'patio.': 1997,
#  'easybroker': 4384,
#  'id:': 8405,
#  'eb-t3055': 1,
#  'emilia': 4,
#  'venta': 29646,
#  'playa': 2665,
#  'carmenfraccionamiento': 1,
#  'selvamar,': 20,
#  'bicisendas,': 3,
#  'canchas': 3336,
#  'tenis': 988,
#  'cesped,': 15,
#  'cenote,': 13,
#  'solarium': 143,
#  'jacuzzi,': 4502,
#  'jardin,alberca': 6,
#  'semiolimpica,': 56,
#  'colegio': 1143,
#  'montessori,a': 2,
#  '10': 12125,
#  '5a.': 43,
#  'avenida,.': 4,
#  'closets,': 6565,
#  'cochera': 39728,
#  'cubierta': 7332,
#  'carros,': 841,
#  'equipada': 15634,
#  'estufa': 4111,
#  'campana': 2269,
#  'tipo': 17977,
#  'isla': 2276,
#  'granito.2': 2,
#  'niveles.': 2794,
#  'construccion': 5415,
#  'nueva.': 566,
#  '<p>pre-venta': 51,
#  'preciosos': 520,
#  'ecologicos': 8,
#  '&nbsp;se': 71,
#  'ejerce': 46,
#  'subsidio': 208,
#  '62,000;': 1,
#  'comedor,': 67666,
#  '&nbsp;tarja': 1,
#  '&nbsp;y': 347,
#  'azulejo': 3028,
#  'cenefa': 89,
#  'decorativa': 356,
#  'barra': 10445,
#  'desayunador,': 7939,
#  '1': 58822,
#  'protecciones': 3553,
#  'puertas': 5402,
#  'ventanas': 4317,
#  'cajon': 1798,
#  'designado': 7,
#  'estacionamiento,': 10222,
#  '&nbsp;enjarre': 1,
#  'general': 1061,
#  'toda': 10019,
#  'vivienda.': 191,
#  'acabados': 23843,
#  'finos.&nbsp;</p>': 1,
#  'terreno': 32298,
#  '5.500m2': 1,
#  'bardeado,': 516,
#  'uso': 6766,
#  'suelo': 3532,
#  'h-200-a,': 1,
#  'plano': 1441,
#  'irregular': 204,
#  'colinda': 617,
#  'al': 57540,
#  'norte': 4616,
#  'circuito': 4077,
#  'exterior': 3528,
#  'mexiquense': 140,
#  '122m2,': 7,
#  '21m2': 11,
#  'sobre': 7890,
#  'las': 69918,
#  'vías': 4528,
#  'más': 11019,
#  'importantes': 1984,
#  'ixtapaluca': 85,
#  'av.': 11202,
#  'morelos': 678,
#  'gasolinera': 102,
#  '42m2.al': 1,
#  'sur': 4368,
#  '105m2': 157,
#  'calle': 16658,
#  'cerrada': 4403,
#  'le': 8136,
#  'da': 2371,
#  'terreno,': 4808,
#  'lado': 2380,
#  'poniente': 1183,
#  '57m2': 16,
#  'campo': 2495,
#  'nave': 146,
#  'industrial': 747,
#  'superficie': 6093,
#  'aproximada': 203,
#  '1.890': 1,
#  'm2': 46851,
#  'construcción': 13254,
#  '250m2': 245,
#  'planta': 64859,
#  'como': 21176,
#  'oficinas': 4185,
#  '<p>mi': 4,
#  '2&deg;': 67,
#  'credito<br': 4,
#  '/>para': 20,
#  'aquellos': 88,
#  'trabajadores': 46,
#  'ya': 10131,
#  'tuvieron': 2,
#  'primer': 7317,
#  'infonavit': 5625,
#  'terminaron': 2,
#  'pagarlo.<br': 1,
#  '/>tienes': 1,
#  'derecho': 533,
#  'tu': 14723,
#  'credito</p>': 82,
#  'nuevo': 5576,
#  ',256': 1,
#  'construccion,un': 1,
#  'piso,acabados': 2,
#  'lujo,elevador': 2,
#  'directo': 3265,
#  'departamento,elevador': 2,
#  'servicio,cocina': 20,
#  ',lavavajillas,': 2,
#  ',boliler,clinas': 1,
#  '5': 19575,
#  'aparatos,': 40,
#  'ilumimacion': 2,
#  ',espejos': 4,
#  ',,1': 1,
#  'bodegas,dos': 1,
#  'cajones': 6248,
#  'estacinamiento': 30,
#  ',vista': 18,
#  'panoramica,amenidades': 2,
#  'alberca,jacuzzi,salon': 2,
#  'eventos,ginmasio,sala': 1,
#  'juntas,': 534,
#  '24': 25530,
#  'hrs': 2259,
#  ',camara': 1,
#  '$7;': 2,
#  '<p><strong>casa': 170,
#  '</strong>en': 34,
#  'golf': 2294,
#  '<strong>zibat&aacute;</strong>,': 1,
#  '141.4': 1,
#  'm': 4292,
#  '170': 586,
#  'construcci&oacute;n,': 724,
#  'jardin': 12893,
#  '98': 255,
#  'm,': 391,
#  'cocina,': 32827,
#  'autos.</p>': 649,
#  'flamante': 15,
#  'habitación': 3558,
#  'condominio': 11089,
#  'horizontal,': 689,
#  'desarrollada': 1760,
#  'baja:': 11308,
#  'estancia,': 9492,
#  'tv,': 12205,
#  'completos,': 9699,
#  'vehículos': 756,
#  'semicubierta;': 1,
#  'matías': 21,
#  'romero,': 99,
#  'colonia': 10475,
#  'valle.': 411,
#  'méxico.': 993,
#  'cochera,': 1841,
#  'horizontal.': 112,
#  '227': 55,
#  '185': 240,
#  'etapa': 1114,
#  '-': 30245,
#  'emplazamiento': 92,
#  'entrega': 13209,
#  '36': 371,
#  'meses': 2728,
#  'solo': 18633,
#  'pagos': 1533,
#  'contado.': 2408,
#  'garantía': 1895,
#  'entrega**invierte': 3,
#  '3\x92': 18,
#  'valor': 7372,
#  'comercial': 11984,
#  '$6\x92.': 1,
#  'remates': 1889,
#  'bancarios': 2002,
#  'son': 11983,
#  'gran': 12716,
#  'opción': 6261,
#  'sión': 107,
#  'no': 30525,
#  'representan': 85,
#  'riesgo': 95,
#  'alguno.': 174,
#  'pre': 609,
#  'residencia': 7953,
#  'toscana': 108,
#  'distribución,': 1106,
#  'todas': 9636,
#  'recamaras.': 2115,
#  '<p>casa': 13128,
#  'recámaras': 23921,
#  'laminados,': 834,
#  'alacena,': 3887,
#  'bodega,': 7092,
#  'terraza,': 12049,
#  'jardín,': 10030,
#  'remodelada,': 1958,
#  '</p>': 14209,
#  '<p>clave:': 16,
#  'vcln2450': 1,
#  'fecha': 1494,
#  'actualizaci&oacute;n': 66,
#  '12/feb/2013.&nbsp;hermosa': 2,
#  'mejores': 5458,
#  'calidad': 3122,
#  'construcci&oacute;n.': 267,
#  'fracc': 912,
#  'cumbres': 1279,
#  'lago': 1844,
#  'juriquilla.&nbsp;superficie:&nbsp;275m2': 1,
#  'y&nbsp;210m2': 1,
#  'construcci&oacute;n.&nbsp;planta': 18,
#  'baja:&nbsp;1/2': 1,
#  'ba&ntilde;o': 15777,
#  'visitas,&nbsp;sala': 3,
#  'comedor,&nbsp;cocina': 9,
#  'integral,&nbsp;cuarto': 2,
#  'servicio,&nbsp;cuarto': 3,
#  'lavado,&nbsp;fuente': 1,
#  'domo': 629,
#  'doble': 14009,
#  'altura,&nbsp;pasillo': 1,
#  'servicio,&nbsp;amplio': 1,
#  'jard&iacute;n': 3290,
#  'jardineras,&nbsp;cochera': 1,
#  'autos,&nbsp;pisos': 1,
#  'porcelanato,&nbsp;planta': 1,
#  'alta:&nbsp;3': 16,
#  'vestidor,&nbsp;balc&oacute;n': 1,
#  'secundarias,&nbsp;sala': 1,
#  'tv,&nbsp;pisos': 2,
#  'laminados': 964,
#  'ba&ntilde;os,&nbsp;llame': 1,
#  'mas': 12796,
#  'informaci&oacute;n:&nbsp;of:': 1,
#  ',&nbsp;nextel:': 1,
#  ',&nbsp;cel:': 1,
#  '&nbsp;id:': 5,
#  '3&nbsp;visita:3</p>': 1,
#  'magnifico': 853,
#  'ventanales': 1204,
#  'techo,': 2055,
#  'balcones': 805,
#  'mucha': 4052,
#  'luz': 5290,
#  'natural,': 2634,
#  'ubicado': 14062,
#  'calles': 3740,
#  'tranquilas': 147,
#  'ángel': 330,
#  'urraza,': 24,
#  'eugenia': 74,
#  'coyoacán.': 142,
#  'edificio': 8501,
#  'hrs.': 5422,
#  'tiene': 36012,
#  '(principal': 862,
#  'vestidor),': 642,
#  'cerrado': 4872,
#  'televisión,': 1400,
#  'sensores': 175,
#  'movimiento': 171,
#  'luces': 520,
#  'áreas': 17242,
#  'comunes': 3712,
#  'roof': 12046,
#  'garden.': 1353,
#  'bukara': 3,
#  'coto': 5544,
#  'club,': 2604,
#  'cual': 3886,
#  'se': 73905,
#  'compone': 170,
#  '100': 2916,
#  'lotes': 1138,
#  'unifamiliares': 40,
#  'conjunto': 6098,
#  'ofrece': 2869,
#  'maravillosa': 454,
#  'club': 8285,
#  'alberca': 13962,
#  'climatizada,': 314,
#  'cancha': 5396,
#  'squash,': 407,
#  'asadores,': 1291,
#  'salones': 838,
#  'usos': 7423,
#  'múltiples': 2158,
#  'juegos': 12795,
#  'infantiles.': 1259,
#  'inigualable': 478,
#  'encuentra': 16393,
#  'tan': 3647,
#  'querétaro': 496,
#  'rodeado': 1689,
#  'servicios,': 3593,
#  'colegios,': 1155,
#  'avenidas': 4076,
#  'primarias': 251,
#  'iii.': 62,
#  '--': 10300,
#  'rcv151104-lv-27': 2,
#  'linda': 2509,
#  'area': 25487,
#  'frente': 16053,
#  'baja': 17535,
#  'estudio': 13058,
#  'moderna': 2074,
#  'abierta,': 1188,
#  'medio': 28366,
#  'visitas,': 11060,
#  'posterior,': 1101,
#  'alacena.': 548,
#  'alta': 17738,
#  'habitaciones': 5851,
#  'compartiendo': 447,
#  'ademas': 2357,
#  'comoda': 630,
#  'tv.': 3277,
#  'porcelanato': 4085,
#  'tienen': 3370,
#  'duela': 3000,
#  'ingenieria': 103,
#  'gusto.': 876,
#  'iluminada,': 2849,
#  'estrene!!!!': 4,
#  '<p>excelente': 5109,
#  'plano,': 2438,
#  'parque': 7939,
#  'cerrada,': 1676,
#  'acceso,': 2700,
#  'plaza': 10542,
#  'cumbres.</p>': 7,
#  'nocnok': 4282,
#  'mx15-bk0340.': 1,
#  'hermosa': 15793,
#  'privado,': 3172,
#  'granito,': 7409,
#  'recámaras,': 19237,
#  'vestidor,': 15714,
#  '3.5': 3089,
#  'roof,': 39,
#  'vista': 23561,
#  'estacionamientos.': 1554,
#  'zibatá?a': 1,
#  'min.': 2674,
#  'universidad': 1775,
#  'anahuác,': 2,
#  '20': 5153,
#  'b.': 204,
#  'quintana': 435,
#  'anillo': 388,
#  'vial': 215,
#  'fray': 197,
#  'junípero': 82,
#  'serra': 45,
#  'antea': 201,
#  '<p>comoda': 81,
#  'fracc.': 4208,
#  'polvorin,': 4,
#  'p.b.': 1723,
#  'gabinetes': 513,
#  'inferiores': 41,
#  'desayunadora,': 1457,
#  'preparacion': 829,
#  'lavado': 27512,
#  'autos.</p>la': 1,
#  'comleto,': 5,
#  'faltan': 307,
#  'muebles': 3874,
#  'llaves.': 19,
#  'esta': 24161,
#  'entrada': 6843,
#  'tanto': 892,
#  'lateral,': 751,
#  'ocuparse': 106,
#  'recamara,': 3655,
#  'adaptarse': 183,
#  'servicio.': 7293,
#  'cancun': 319,
#  'habitaciones,': 3910,
#  'espaciosa': 826,
#  'recibidor': 2658,
#  'alberca,': 10332,
#  'autos': 18588,
#  'semi': 1375,
#  'techado,': 2752,
#  'a/a': 414,
#  'cortinas.': 179,
#  'gimnasios,': 647,
#  'restaurantes,': 2168,
#  'deportivo,': 186,
#  'principales,': 1095,
#  'privada.': 1305,
#  'pesos.': 2095,
#  'estimado': 145,
#  'cliente,': 144,
#  'península,': 72,
#  'placer': 265,
#  'atenderle,': 68,
#  'esperamos': 130,
#  'llamada': 339,
#  '(998)': 235,
#  'mándenos': 4,
#  'email': 308,
#  'a:': 439,
#  '<p>propiedad': 265,
#  'nivel,': 4777,
#  'espacios': 12976,
#  'e': 11338,
#  'iluminados,bardas': 2,
#  'perimetrales': 348,
#  '5mtscochera': 2,
#  '&nbsp;&nbsp;buen': 1,
#  'conservaci&oacute;n': 135,
#  'estudio,': 15049,
#  'perfecto': 1281,
#  'estado,': 1769,
#  '&aacute;rea': 5652,
#  'ar&eacute;a': 8,
#  'tendido': 2953,
#  'altarecamara': 7,
#  'jacuzzie.</p>': 1,
#  '<p>c721</p>': 1,
#  'santa': 7088,
#  'cecilia': 134,
#  'apodaca,': 146,
#  'automóvil,': 106,
#  'recientemente': 291,
#  'instalada,': 33,
#  'lavandería': 4621,
#  'techada,': 6372,
#  'amplio,': 3805,
#  'alta,': 3144,
#  'comparten': 9040,
#  'vestidor.': 3666,
#  '¡excelente': 320,
#  'oportunidad!': 899,
#  'nivel': 14128,
#  'misiones': 114,
#  'francisco,': 141,
#  'vw': 30,
#  'outlet.': 28,
#  '\x952': 89,
#  '\x95sala-comedor': 4,
#  '\x95cocina': 94,
#  '\x95un': 9,
#  'completo': 32700,
#  'calentador': 3730,
#  '\x95patio': 27,
#  '\x95estacionamiento': 24,
#  'auto': 5533,
#  'acepto': 2726,
#  'tramito': 185,
#  'crédito': 7463,
#  'lujo,': 5299,
#  'family': 3910,
#  'room,': 2160,
#  'despacho,': 953,
#  'gym,': 2412,
#  'cava,': 394,
#  'calefaccion,': 332,
#  'jardines,': 2076,
#  'terrazas.': 338,
#  'información': 3894,
#  'visita': 1106,
#  'nuestra': 2437,
#  'página': 420,
#  'sala-comedor,': 10173,
#  'horas.': 3575,
#  'urbanización': 186,
#  'progresiva,': 1,
#  'regular,': 198,
#  'campestre': 862,
#  'otra': 3740,
#  'velador.': 15,
#  'entorno': 1393,
#  'habitacional': 2886,
#  'industrial.': 162,
#  'fácil': 2085,
#  'varias': 919,
#  'comunicación.': 282,
#  'hav1407e-285': 1,
#  'venta,': 3468,
#  'medio.': 428,
#  'bien': 14296,
#  'ubicados': 1082,
#  'mercado': 1564,
#  'unas': 2422,
#  'cuantas': 102,
#  'cuadras': 6943,
#  'avenida': 5931,
#  'monterrey.': 313,
#  '&iexcl;ven': 19,
#  'conocelos!': 3,
#  '<p>vendo': 1080,
#  'lomas': 6351,
#  'alfonso': 196,
#  'calera</p>': 1,
#  '<p>precio:': 160,
#  '<p>t:': 47,
#  '196': 100,
#  'metros</p>': 80,
#  '<p>c:': 36,
#  '143': 121,
#  '<p>caracteristicas</p>': 26,
#  '<p>planta': 1499,
#  'amplio.</p>': 67,
#  'alta:': 10689,
#  'ba&ntilde;o.</p>': 319,
#  '<p>otros:': 18,
#  'cisterna,': 6573,
#  'horas': 4249,
#  'dia.</p>': 16,
#  '<p>informes': 373,
#  'grupo': 310,
#  'ficasa</p>': 18,
#  '<p>': 2141,
#  '/': 6634,
#  '</p><p>sala,': 569,
#  'x': 7820,
#  '5m': 67,
#  'andador': 294,
#  'piedra': 1851,
#  'antiderrapante,': 51,
#  'frontal': 1130,
#  'trasero': 5444,
#  'iluminación': 4088,
#  'led': 567,
#  '</p><p>cocina': 2672,
#  'vestida': 767,
#  'poplar': 39,
#  'abierta': 2103,
#  '</p><p>1': 1166,
#  'visitas': 7189,
#  'meseta': 2242,
#  '</p><p>cochera': 1542,
#  'porton': 4043,
#  'automatico': 178,
#  '</p><p>piso': 244,
#  'concreto': 2691,
#  'estampado.': 124,
#  '</p><p>cuarto': 1566,
#  'techo': 4040,
#  'lavadora/secadora': 17,
#  'batea': 55,
#  'clásica': 26,
#  '</p><p>': 60911,
#  '</p><p>planta': 5985,
#  '</p><p>3': 1840,
#  'closets': 8675,
#  'vestidos,': 242,
#  'canceles': 2829,
#  'cristal': 4994,
#  'templado': 2343,
#  'mesetas': 1272,
#  '</p><p>sala': 2467,
#  'tv': 8443,
#  '</p><p>equipamiento:': 343,
#  '</p><p>pisos': 441,
#  '60x60cm': 8,
#  '</p><p>sistema': 214,
#  'hidroneumatico': 508,
#  'pozos': 176,
#  'llenado': 200,
#  'vaciado': 5,
#  'riego': 1875,
#  '</p><p>malla': 7,
#  'ciclonica': 38,
#  '1.5m': 10,
#  'altura': 5140,
#  'alrededor': 579,
#  'casa.': 3088,
#  '</p><p>gas': 72,
#  'estacionario': 3535,
#  '180': 1314,
#  'litros': 1589,
#  '</p><p>cuenta': 1551,
#  'agua': 5981,
#  'potable': 512,
#  'y/o': 2456,
#  'pozo': 1107,
#  'abastecimiento': 78,
#  '</p><p>todas': 128,
#  'ahorradores': 246,
#  'energia': 96,
#  '</p><p>las': 401,
#  'equipos': 536,
#  'mirage': 22,
#  'aire': 7120,
#  'inverter': 86,
#  'también': 3495,
#  'persianas': 2303,
#  'tecnoblinds': 2,
#  'así': 2747,
#  'ventiladores': 1283,
#  'áreas.</p>': 13,
#  'plantas,': 6446,
#  'hall': 3188,
#  'distribucion,': 382,
#  '350m2': 135,
#  '300m2': 369,
#  'construccion,': 1440,
#  'otras': 7860,
#  'grandes,': 759,
#  'ellas': 3193,
#  'balcon,': 1194,
#  'lugares': 8917,
#  'estacionamiento.': 8271,
#  'chimenea,': 3107,
#  'recibidor,': 5812,
#  'salon': 5206,
#  'juegos,': 4020,
#  'jardin,': 5044,
#  '<p>for': 425,
#  'primero': 563,
#  'ellos': 1244,
#  'segundo': 8327,
#  'balcón;': 66,
#  'además': 4369,
#  'propiedad': 13181,
#  'encontramos': 532,
#  'palapa,': 1296,
#  'verdes': 6956,
#  'disfrutar': 2243,
#  'compañía': 235,
#  'familia.': 1050,
#  'aproveche': 2174,
#  'adquiera': 457,
#  'ellas.': 55,
#  'ventas': 1039,
#  'teléfonos': 1165,
#  'ó': 2690,
#  '50.': 405,
#  'for': 1105,
#  'pagina': 1301,
#  'web:</p>': 400,
#  '<p>bonito': 739,
#  'juriquilla,': 696,
#  'varios': 1152,
#  'modelos': 888,
#  'precios:': 67,
#  '</p><p>-vista': 9,
#  'panoramica': 751,
#  '</p><p>-jardines': 9,
#  'comunal': 362,
#  '</p><p>-sala': 339,
#  '</p><p>-estudio': 53,
#  '</p><p>-jardin': 32,
#  '</p><p>-sisterna': 1,
#  '</p><p>-cocina': 325,
#  '</p><p>-hidroneumatico': 5,
#  '</p><p>-vigilancia': 54,
#  'horas</p>': 85,
#  'céntrica': 705,
#  'parte': 7876,
#  'trasera': 1157,
#  'amplios,': 3748,
#  'inundable,': 29,
#  'importantes,': 301,
#  'comercios': 1121,
#  'tiendas': 2609,
#  'autoservicio.': 316,
#  '</p><p>v-201': 3,
#  '</p><p>ll135': 3,
#  '</p><p>tel:': 462,
#  '</p><p>a-zh31</p><p>otras': 11,
#  'características:</p><p>espacios': 3659,
#  'autos:': 4201,
#  '1,': 1435,
#  'hermoso': 5882,
#  'buen': 11285,
#  'gusto': 4619,
#  'estilo': 8993,
#  'moderno.': 348,
#  'baños.': 3385,
#  'opcion': 2530,
#  'negociar': 342,
#  'muebles,': 463,
#  'cantina': 921,
#  'empotrados': 336,
#  'medida.': 83,
#  '¡cuenta': 2,
#  'vigilancia!': 12,
#  '<p>ubicado': 259,
#  'nororiente': 21,
#  'mérida,': 579,
#  'real': 3190,
#  'montejo': 137,
#  'cruzando': 79,
#  'periférico': 2042,
#  'rumbo': 196,
#  'dzitia,': 1,
#  'cuarta': 1598,
#  'han': 325,
#  'modificado': 25,
#  'aumentado': 4,
#  'diseño': 4205,
#  'adaptando': 4,
#  'espacio': 16069,
#  'más,': 325,
#  'principal.': 1387,
#  '</p><p></p>': 6964,
#  'mts': 8209,
#  'arcó': 14,
#  'triunfo': 28,
#  ...}
